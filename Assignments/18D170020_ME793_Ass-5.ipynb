# %% [markdown]
# #Assignment 5
# Moitreyee Sarkar- 18D170020

# %% [markdown]
# #Q.1
# Task 1- Take the same dataset as that of Assignment 3 & 4 which has 7 columns.

# %%
#import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
#mounting drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#read excel data file
df = pd.read_excel('/content/drive/MyDrive/Periodic_table_data.xlsx')             #here I'm using same data as that of Assignment 3 & 4
df
# Out:
#     Symbol  Atomic Number  Electronegativity  Atomic Radii (pm)  \
# 0        H              1               2.20               53.0
# 1       He              2                NaN               31.0
# 2       Li              3               0.98              167.0
# 3       Be              4               1.57              112.0
# 4        B              5               2.04               87.0
# ..     ...            ...                ...                ...
# 113     Fl            114                NaN                NaN
# 114     Mc            115                NaN                NaN
# 115     Lv            116                NaN                NaN
# 116     Ts            117                NaN                NaN
# 117     Og            118                NaN                NaN
#
#      Thermal Conductivity   Density       Crystal System
# 0                  0.1805  0.000090     Simple Hexagonal
# 1                  0.1513  0.000179  Face Centered Cubic
# ...

# %%
print("Total number of columns:", df.shape[1])
# Out:
# Total number of columns: 7

# %%
# Function to select dataset
def call(functionToCall):
    print('\nTable\n')
    functionToCall(df)

# %%
# Remove spaces from column names
def q1(Periodic_table_data):
    Periodic_table_data.columns = [x.strip().replace(' ','_') for x in Periodic_table_data.columns]
call(q1)
df.head()
# Out:
# Table
#   Symbol  Atomic_Number  Electronegativity  Atomic_Radii_(pm)  \
# 0      H              1               2.20               53.0
# 1     He              2                NaN               31.0
# 2     Li              3               0.98              167.0
# 3     Be              4               1.57              112.0
# 4      B              5               2.04               87.0
#
#    Thermal_Conductivity   Density       Crystal_System
# 0                0.1805  0.000090     Simple Hexagonal
# 1                0.1513  0.000179  Face Centered Cubic
# 2               85.0000  0.534000  Body Centered Cubic
# 3              190.0000  1.850000     Simple Hexagonal
# 4               27.0000  2.340000      Simple Trigonal

# %% [markdown]
# Task 2- Sort the table according to the increasing order of thermal conductivity.

# %%
#drop null values
df = df.dropna()
df
# Out:
#    Symbol  Atomic_Number  Electronegativity  Atomic_Radii_(pm)  \
# 0       H              1               2.20               53.0
# 2      Li              3               0.98              167.0
# 3      Be              4               1.57              112.0
# 4       B              5               2.04               87.0
# 5       C              6               2.55               67.0
# ..    ...            ...                ...                ...
# 79     Hg             80               2.00              171.0
# 80     Tl             81               2.04              156.0
# 81     Pb             82               2.33              154.0
# 82     Bi             83               2.02              143.0
# 84     At             85               2.20              127.0
#
#     Thermal_Conductivity   Density            Crystal_System
# 0                 0.1805   0.00009          Simple Hexagonal
# 2                85.0000   0.53400       Body Centered Cubic
# ...

# %%
#sorting in ascending order
df.sort_values(by=['Thermal_Conductivity'], inplace=True)
df
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
#    Symbol  Atomic_Number  Electronegativity  Atomic_Radii_(pm)  \
# 16     Cl             17               3.16               79.0
# 6       N              7               3.04               56.0
# 7       O              8               3.44               48.0
# 8       F              9               3.98               42.0
# 34     Br             35               2.96               94.0
# ..    ...            ...                ...                ...
# 19     Ca             20               1.00              194.0
# 12     Al             13               1.61              118.0
# 78     Au             79               2.54              174.0
# ...

# %% [markdown]
# Task 3- Now divide the
# complete data into 7 subgroups of thermal conductivity. Suppress the groups 2, 4 and 6.

# %%
#Other properties removed from this table
df0 = df[['Thermal_Conductivity']]
df0
# Out:
#     Thermal_Conductivity
# 16               0.00890
# 6                0.02583
# 7                0.02658
# 8                0.02770
# 34               0.12000
# ..                   ...
# 19             200.00000
# 12             235.00000
# 78             320.00000
# 28             400.00000
# 46             430.00000
#
# [79 rows x 1 columns]

# %%
#Group 1 shuffled
df1 = df0.iloc[0:11]
x1 = df1.sample(frac=1)
x1
# Out:
#     Thermal_Conductivity
# 33               0.52000
# 52               0.44900
# 6                0.02583
# 84               2.00000
# 7                0.02658
# 15               0.20500
# 0                0.18050
# 8                0.02770
# 34               0.12000
# 16               0.00890
# 14               0.23600

# %%
#Group 3 shuffled
df3 = df0.iloc[21:37]
x3 = df3.sample(frac=1)
x3
# Out:
#     Thermal_Conductivity
# 68                  17.0
# 60                  15.0
# 39                  23.0
# 70                  16.0
# 50                  24.0
# 71                  23.0
# 67                  15.0
# 21                  22.0
# 4                   27.0
# 62                  14.0
# 59                  17.0
# 61                  13.0
# 38                  17.0
# 20                  16.0
# 66                  16.0
# 55                  18.0

# %%
#Group 5 shuffled
df5 = df0.iloc[51:63]
x5 = df5.sample(frac=1)
x5
# Out:
#     Thermal_Conductivity
# 23                  94.0
# 27                  91.0
# 25                  80.0
# 48                  82.0
# 49                  67.0
# 26                 100.0
# 2                   85.0
# 18                 100.0
# 45                  72.0
# 47                  97.0
# 77                  72.0
# 75                  88.0

# %%
#Group 7 shuffled
df7 = df0.iloc[77:79]
x7 = df7.sample(frac=1)
x7
# Out:
#     Thermal_Conductivity
# 28                 400.0
# 46                 430.0

# %% [markdown]
# Task 4- Apply k-Means method and show that there are 4 groups of elements.

# %%
X = np.concatenate((x1,x3,x5,x7),axis=0)
plt.plot(X[:,0],'k.')
#plt.plot(X[:,0],X[:,1],'k.')
plt.show()

# %%
from sklearn.cluster import KMeans

# %%
n = 4
k_means = KMeans(n_clusters=n)
k_means.fit(X)
# Out:
# KMeans(n_clusters=4)

# %%
centroids = k_means.cluster_centers_
labels= k_means.labels_

# %%
plt.plot(X[labels==0,0],'r.', label='cluster 1')
plt.plot(X[labels==1,0],'b.', label='cluster 2')
plt.plot(X[labels==2,0],'g.', label='cluster 3')
plt.plot(X[labels==3,0],'k.', label='cluster 4')
plt.plot(centroids[:,0],'mo',markersize=8, label='centroids')

plt.legend(loc='best')
plt.show()

# %% [markdown]
# So,  there are 4 groups of elements.

# %% [markdown]
# # Q.2
# Apply k-Means method on this data and reveal how many groups it has. Dataset - Micrographs of Metals.
# The final results should include (a) elbow plot and (b) graphics of clusters or ‘blobs’ in PC space.

# %%
import cv2 
import os 
import glob 
img_dir = "" # Enter Directory of all images  
data_path = os.path.join(img_dir,'*g') 
files = glob.glob(data_path) 
data = [] 
for f1 in files: 
    img = cv2.imread(f1) 
    data.append(img)
